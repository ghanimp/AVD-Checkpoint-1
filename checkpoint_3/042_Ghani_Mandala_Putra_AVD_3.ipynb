# %% [markdown]
# # Checkpoint 1

# %% [markdown]
# # BUSINESS UNDERSTANDING

# %% [markdown]
# ## Business Objective

# %% [markdown]
# Proyek ini bertujuan untuk mengembangkan model prediksi harga laptop yang akurat berdasarkan spesifikasi. Model ini akan membantu konsumen, retailer, dan produsen dalam menetapkan harga yang adil, mengoptimalkan strategi harga, serta membuat keputusan berbasis data. Dengan memahami faktor-faktor yang mempengaruhi harga dan memanfaatkan analitik data, proyek ini akan menciptakan sistem prediksi yang transparan dan efisien di pasar laptop.

# %% [markdown]
# ## Asses Situation

# %% [markdown]
# Situasi bisnis yang mendasari analisis ini adalah lingkungan pasar yang semakin kompetitif dan dinamis di industri teknologi, khususnya dalam penjualan laptop. Perkembangan teknologi, dan variasi spesifikasi produk mengharuskan perusahaan untuk memiliki pemahaman yang mendalam tentang faktor-faktor yang memengaruhi harga laptop. Pengembangan model prediksi harga berbasis spesifikasi menjadi penting untuk meningkatkan efisiensi operasional, membantu strategi penetapan harga, dan memberikan rekomendasi yang lebih akurat kepada pelanggan. Oleh karena itu, analisis prediksi harga laptop berdasarkan spesifikasi menjadi krusial dalam mengidentifikasi peluang dan tantangan dalam menghadapi pasar teknologi yang terus berkembang.

# %% [markdown]
# ## Data Mining Goals

# %% [markdown]
# Dengan mencari informasi tentang spesifikasi laptop, dapat membantu mengidentifikasi dan menganalisis faktor-faktor yang mempengaruhi harga laptop berdasarkan berbagai aspek seperti merek, spesifikasi teknis, perangkat lunak, serta tambahan aksesori dan desain. Selain itu, analisis dapat mengungkap sejauh mana faktor estetika dan merek dapat menentukan suatu harga laptop.

# %% [markdown]
# ## Project Plan

# %% [markdown]
# Proyek ini akan dimulai dengan penelitian mengenai faktor-faktor yang memengaruhi harga laptop, seperti merek, spesifikasi teknis, perangkat lunak bawaan, aksesori tambahan, dan desain. Tahap awal mencakup pengumpulan data dari berbagai sumber, termasuk e-commerce dan situs resmi produsen laptop. Setelah data terkumpul, analisis eksploratif akan dilakukan untuk mengidentifikasi tren harga serta faktor dominan yang berpengaruh. Selain itu, proyek ini juga akan mengevaluasi dampak paket pembelian terhadap harga laptop, termasuk apakah keberadaan aksesori seperti monitor, keyboard, mouse, atau printer memberikan nilai tambah yang signifikan. Pada tahap akhir, hasil penelitian akan dirangkum dalam laporan analitis yang dilengkapi dengan visualisasi data, memberikan wawasan mendalam mengenai strategi penetapan harga di industri laptop.

# %% [markdown]
# # Checkpoint 2

# %% [markdown]
# # DATA UNDERSTANDING

# %% [markdown]
# Link Dataset https://www.kaggle.com/datasets/arnabchaki/laptop-price-prediction

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("laptops_test.csv")

df
# Out:
#     Manufacturer                           Model Name            Category  \
# 0             HP    15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1           Asus                     Rog GL753VE-DS74              Gaming
# 2           Dell                        Inspiron 7579  2 in 1 Convertible
# 3        Toshiba                    Portege Z30-C-1CV            Notebook
# 4         Lenovo                    IdeaPad 320-15ABR            Notebook
# ..           ...                                  ...                 ...
# 320       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 321       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 322       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 323           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 324         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#     Screen Size                                      Screen  \
# ...

# %%
print(f"Dataset memiliki {df.shape[0]} baris dan {df.shape[1]} kolom.\n")
# Out:
# Dataset memiliki 325 baris dan 13 kolom.

# %% [markdown]
# Disini saya menampilkan jumllah dataset yang masih belum dianalisis, berjumlah 325 baris dan 13 kolom.

# %% [markdown]
# # Cek tipe data setiap kolom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              325 non-null    object
#  1   Model Name                325 non-null    object
#  2   Category                  325 non-null    object
#  3   Screen Size               325 non-null    object
#  4   Screen                    325 non-null    object
#  5   CPU                       325 non-null    object
#  6   RAM                       325 non-null    object
#  7    Storage                  325 non-null    object
#  8   GPU                       325 non-null    object
#  9   Operating System          325 non-null    object
#  10  Operating System Version  291 non-null    object
#  11  Weight                    325 non-null    object
#  12  Price                     325 non-null    float64
# dtypes: float64(1), object(12)
# ...

# %%
df.describe()
# Out:
#               Price
# count  3.250000e+02
# mean   9.891671e+06
# std    5.943217e+06
# min    1.547208e+06
# 25%    5.317416e+06
# 50%    8.892000e+06
# 75%    1.332022e+07
# max    3.534570e+07

# %% [markdown]
# # Data cleaning

# %% [markdown]
# **1. Missing Value**

# %% [markdown]
# Selanjutnya saya mencari mising value dari dataset ini.

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Manufacturer                 0.000000
# Model Name                   0.000000
# Category                     0.000000
# Screen Size                  0.000000
# Screen                       0.000000
# CPU                          0.000000
# RAM                          0.000000
#  Storage                     0.000000
# GPU                          0.000000
# Operating System             0.000000
# Operating System Version    10.461538
# Weight                       0.000000
# Price                        0.000000
# dtype: float64

# %% [markdown]
# di kolom operating system version terdapat 10% data yang hilang.

# %%
df[df['Operating System Version'].isnull()]
# Out:
#     Manufacturer                             Model Name            Category  \
# 14        Lenovo         V110-15IAP (N3350/4GB/128GB/No            Notebook
# 71          Asus                      Chromebook C202SA             Netbook
# 78            HP                                 250 G5            Notebook
# 83          Asus                      Rog G752VL-GC088D              Gaming
# 110           HP                          Chromebook 13            Notebook
# 112         Dell                          Inspiron 3552            Notebook
# 113           HP                                 250 G6            Notebook
# 124         Acer                          Chromebook 15            Notebook
# 136       Lenovo                              Yoga Book  2 in 1 Convertible
# 145         Dell                         Latitude E5570            Notebook
# 150       Lenovo                     Legion Y520-15IKBN              Gaming
# ...

# %%
df['Operating System Version'].dropna().describe()
# Out:
# count     291
# unique      3
# top        10
# freq      252
# Name: Operating System Version, dtype: object

# %% [markdown]
# **2. Duplicated Values**

# %% [markdown]
# Selanjutnnya saya melakukan analilsis data yang duplikat

# %%
df[df.duplicated()]
# Out:
#     Manufacturer                                 Model Name  \
# 297         Asus                       ZenBook UX305CA-UBM1
# 298         Dell                              Inspiron 3567
# 299         Acer                             Aspire ES1-531
# 300         Dell                              Inspiron 3552
# 301       Lenovo                         IdeaPad Y700-15ISK
# 302           HP                        Pavilion 15-AW003nv
# 303         Dell                              Inspiron 3567
# 304           HP                           Stream 11-Y000na
# 305         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 306       Lenovo                             Yoga 500-14ISK
# 307       Lenovo                             Yoga 900-13ISK
# 308       Lenovo                         IdeaPad 100S-14IBR
# 309           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 310         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
# 311         Asus                       ZenBook UX305CA-UBM1
# ...

# %% [markdown]
# didalam dataset ini ditemukan sebanyak 28 data duplikat

# %%
df = df.drop_duplicates()

# %% [markdown]
# selanjutnya data yang duplikat saya hapus

# %%
df
# Out:
#     Manufacturer                           Model Name            Category  \
# 0             HP    15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1           Asus                     Rog GL753VE-DS74              Gaming
# 2           Dell                        Inspiron 7579  2 in 1 Convertible
# 3        Toshiba                    Portege Z30-C-1CV            Notebook
# 4         Lenovo                    IdeaPad 320-15ABR            Notebook
# ..           ...                                  ...                 ...
# 292       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 293       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 294       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 295           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 296         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#     Screen Size                                      Screen  \
# ...

# %% [markdown]
# # Melakukan Imputasi

# %% [markdown]
# disini saya mengganti nilai yang hilang padakolom operating system version, dengan menyesuaikan os pada laptop yang ada, saya mengguanakan metode ini karena lebih efektif dibanding menggunakan mean karena jenis os yang berbeda, dan tidak saya hapus karena jumlah data yang hilang cukup banhyak

# %%
df.loc[df["Operating System"] == "Windows", "Operating System Version"] = df.loc[df["Operating System"] == "Windows", "Operating System Version"].fillna("Windows 10")
df.loc[df["Operating System"] == "macOS", "Operating System Version"] = df.loc[df["Operating System"] == "macOS", "Operating System Version"].fillna("macOS Monterey")
df.loc[df["Operating System"] == "Linux", "Operating System Version"] = df.loc[df["Operating System"] == "Linux", "Operating System Version"].fillna("Ubuntu 22.04")

# %%
df[df['Operating System Version'].isnull()]
# Out:
#     Manufacturer                             Model Name            Category  \
# 14        Lenovo         V110-15IAP (N3350/4GB/128GB/No            Notebook
# 71          Asus                      Chromebook C202SA             Netbook
# 78            HP                                 250 G5            Notebook
# 83          Asus                      Rog G752VL-GC088D              Gaming
# 110           HP                          Chromebook 13            Notebook
# 113           HP                                 250 G6            Notebook
# 124         Acer                          Chromebook 15            Notebook
# 136       Lenovo                              Yoga Book  2 in 1 Convertible
# 150       Lenovo                     Legion Y520-15IKBN              Gaming
# 172       Lenovo        V110-15ISK (i3-6006U/4GB/1TB/No            Notebook
# 174       Lenovo        B51-80 (i5-6200U/8GB/1TB/Radeon            Notebook
# ...

# %%
df
# Out:
#     Manufacturer                           Model Name            Category  \
# 0             HP    15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1           Asus                     Rog GL753VE-DS74              Gaming
# 2           Dell                        Inspiron 7579  2 in 1 Convertible
# 3        Toshiba                    Portege Z30-C-1CV            Notebook
# 4         Lenovo                    IdeaPad 320-15ABR            Notebook
# ..           ...                                  ...                 ...
# 292       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 293       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 294       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 295           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 296         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#     Screen Size                                      Screen  \
# ...

# %%
df['Operating System Version'] = df['Operating System Version'].fillna('Unknown')

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Manufacturer                0.0
# Model Name                  0.0
# Category                    0.0
# Screen Size                 0.0
# Screen                      0.0
# CPU                         0.0
# RAM                         0.0
#  Storage                    0.0
# GPU                         0.0
# Operating System            0.0
# Operating System Version    0.0
# Weight                      0.0
# Price                       0.0
# dtype: float64

# %% [markdown]
# sekarang dataset sudah lengkap

# %% [markdown]
# **3. Outliers**

# %%
df["Weight"].unique()
# Out:
# array(['2.04kg', '2.99kg', '2.19kg', '1.2kg', '2.2kg', '2.3kg', '1.75kg',
#        '2.25kg', '2.5kg', '2.36kg', '1.6kg', '0.97kg', '2.1kg', '1.9kg',
#        '1.68kg', '1.4kg', '1.11kg', '2.4kg', '1.48kg', '2.7kg', '1.34kg',
#        '2.18kg', '1.64kg', '1.95kg', '1.43kg', '2.65kg', '1.26kg',
#        '1.54kg', '1.49kg', '1.5kg', '1.47kg', '2.08kg', '2.09kg',
#        '2.31kg', '1.29kg', '2.63kg', '1.84kg', '1.8kg', '1.45kg',
#        '3.78kg', '4.6kg', '1.1kg', '1.91kg', '1.96kg', '2.94kg', '4kgs',
#        '2.32kg', '3.58kg', '1.62kg', '3.21kg', '0.920kg', '2.06kg',
#        '1.3kg', '3.0kg', '0.99kg', '0.69kg', '1.7kg', '1.86kg', '2.6kg',
#        '4.3kg', '2.20kg', '2.9kg', '2.59kg', '1.16kg', '2.24kg', '1.23kg',
#        '1.25kg', '1.05kg', '3.52kg', '1.35kg', '2kg', '3.35kg', '2.23kg',
#        '3kg', '1.88kg', '2.8kg', '2.0kg', '1.27kg', '2.62kg', '1.44kg',
#        '3.31kg', '2.07kg', '1.36kg', '1.98kg', '2.591kg', '4.2kg',
# ...

# %%
df["Weight"] = df["Weight"].str.replace("kgs", "").str.replace("kg", "").astype(float)

# %%
df["Weight"].unique()
# Out:
# array([2.04 , 2.99 , 2.19 , 1.2  , 2.2  , 2.3  , 1.75 , 2.25 , 2.5  ,
#        2.36 , 1.6  , 0.97 , 2.1  , 1.9  , 1.68 , 1.4  , 1.11 , 2.4  ,
#        1.48 , 2.7  , 1.34 , 2.18 , 1.64 , 1.95 , 1.43 , 2.65 , 1.26 ,
#        1.54 , 1.49 , 1.5  , 1.47 , 2.08 , 2.09 , 2.31 , 1.29 , 2.63 ,
#        1.84 , 1.8  , 1.45 , 3.78 , 4.6  , 1.1  , 1.91 , 1.96 , 2.94 ,
#        4.   , 2.32 , 3.58 , 1.62 , 3.21 , 0.92 , 2.06 , 1.3  , 3.   ,
#        0.99 , 0.69 , 1.7  , 1.86 , 2.6  , 4.3  , 2.9  , 2.59 , 1.16 ,
#        2.24 , 1.23 , 1.25 , 1.05 , 3.52 , 1.35 , 2.   , 3.35 , 2.23 ,
#        1.88 , 2.8  , 1.27 , 2.62 , 1.44 , 3.31 , 2.07 , 1.36 , 1.98 ,
#        2.591, 4.2  , 1.15 , 2.21 , 2.43 , 3.3  , 2.191, 1.08 , 2.77 ,
#        2.34 , 1.24 , 2.29 , 1.17 ])

# %%
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers

outliers_price = detect_outliers_iqr(df, "Price")
outliers_weight = detect_outliers_iqr(df, "Weight")

len(outliers_price), outliers_price.head(), len(outliers_weight), outliers_weight.head()
# Out:
# (6,
#      Manufacturer          Model Name     Category Screen Size  \
#  39        Lenovo        ThinkPad P70     Notebook       17.3"
#  88          Asus          ROG G701VO       Gaming       17.3"
#  103       Lenovo  IdeaPad Y900-17ISK       Gaming       17.3"
#  125           HP            ZBook 17  Workstation       17.3"
#  158           HP            ZBook 17  Workstation       17.3"
#
#                                Screen                          CPU   RAM  \
#  39   IPS Panel 4K Ultra HD 3840x2160  Intel Core i7 6820HQ 2.7GHz  16GB
#  88       IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz  64GB
#  103      IPS Panel Full HD 1920x1080  Intel Core i7 6820HK 2.7GHz  32GB
#  125      IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz   8GB
#  158      IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz   8GB
#
#                       Storage                      GPU Operating System  \
# ...

# %% [markdown]
# # Incosistent value

# %%
df
# Out:
#     Manufacturer                           Model Name            Category  \
# 0             HP    15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1           Asus                     Rog GL753VE-DS74              Gaming
# 2           Dell                        Inspiron 7579  2 in 1 Convertible
# 3        Toshiba                    Portege Z30-C-1CV            Notebook
# 4         Lenovo                    IdeaPad 320-15ABR            Notebook
# ..           ...                                  ...                 ...
# 292       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 293       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 294       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 295           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 296         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#     Screen Size                                      Screen  \
# ...

# %% [markdown]
# Menurut saya dataset ini cukup konsisten

# %% [markdown]
# # Construct Data

# %%
df["Screen Size"] = df["Screen Size"].astype(str).str.replace('"', '', regex=False)

df["Screen Size"] = pd.to_numeric(df["Screen Size"], errors="coerce")

# %%
def classify_device(row):
    if row["Category"] in ["Ultrabook", "Gaming", "Notebook", "Convertible"]:
        return "Laptop"
    elif row["Screen Size"] > 17.3 or row["Weight"] > 3.5:
        return "Desktop"
    else:
        return "Other"

# Menambahkan kolom baru "Device Type"
df["Device Type"] = df.apply(classify_device, axis=1)

# Menyimpan hasil ke file baru
df.to_csv("laptops_with_device_type.csv", index=False)

# Menampilkan beberapa baris pertama
print(df.head())
# Out:
#   Manufacturer                         Model Name            Category  \
# 0           HP  15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1         Asus                   Rog GL753VE-DS74              Gaming
# 2         Dell                      Inspiron 7579  2 in 1 Convertible
# 3      Toshiba                  Portege Z30-C-1CV            Notebook
# 4       Lenovo                  IdeaPad 320-15ABR            Notebook
#
#    Screen Size                                     Screen  \
# 0          NaN                                   1366x768
# 1          NaN                          Full HD 1920x1080
# 2          NaN  IPS Panel Full HD / Touchscreen 1920x1080
# 3          NaN                          Full HD 1920x1080
# 4          NaN                          Full HD 1920x1080
#
#                            CPU   RAM               Storage  \
# 0   Intel Core i7 7500U 2.7GHz   6GB               1TB HDD
# 1  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# ...

# %% [markdown]
# disini saya menambahkan kolom device type untuk membedakan laptop dan desktop

# %% [markdown]
# # Data Reduction

# %%
df_desktop = df[df["Device Type"] == "Desktop"]
print(df_desktop)
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model Name, Category, Screen Size, Screen, CPU, RAM,  Storage, GPU, Operating System, Operating System Version, Weight, Price, Device Type]
# Index: []

# %% [markdown]
# Karena kolom yang saya buat tadi tidak cukup berguna dan hanya memboros kolom maka  kolom device type saya hapus

# %%
del df["Device Type"]

# %%
df
# Out:
#     Manufacturer                           Model Name            Category  \
# 0             HP    15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1           Asus                     Rog GL753VE-DS74              Gaming
# 2           Dell                        Inspiron 7579  2 in 1 Convertible
# 3        Toshiba                    Portege Z30-C-1CV            Notebook
# 4         Lenovo                    IdeaPad 320-15ABR            Notebook
# ..           ...                                  ...                 ...
# 292       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 293       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 294       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 295           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 296         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#      Screen Size                                      Screen  \
# ...

# %% [markdown]
# # Checkpoint 3

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Bar chart Seaborn
plt.figure(figsize=(8, 5))
sns.barplot(x=df["RAM"].value_counts().index, y=df["RAM"].value_counts().values, color='blue')
plt.title("Jumlah Laptop berdasarkan RAM")
plt.xlabel("RAM (GB)")
plt.ylabel("Jumlah Laptop")
plt.xticks(rotation=45)
plt.show()

# %%
# Pie chart: Distribusi kategori laptop
plt.figure(figsize=(7, 7))
plt.pie(df["Category"].value_counts(), labels=df["Category"].value_counts().index, autopct='%1.1f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold', 'violet', 'orange'])
plt.title("Distribusi Kategori Laptop")
plt.show()

# %%
# Line Chart (Matplotlib): tren harga rata-rata berdasarkan kategori laptop
df_price_trend = df.groupby("Manufacturer")["Price"].mean()

plt.figure(figsize=(10, 5))
plt.plot(df_price_trend.index, df_price_trend.values, marker='o', linestyle='-', color='purple')
plt.title("Tren Harga Rata-rata per Merek Laptop")
plt.xlabel("Merek Laptop")
plt.ylabel("Harga Rata-rata")
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# Karena dataset laptops_test tidak memiliki kolom tanggal, saya membuat Line Chart untuk tren harga rata-rata laptop berdasarkan kategori atau merk.

# %%
# Line Chart Seaborn
df_price_trend = df.groupby("Manufacturer")["Price"].mean().reset_index()

plt.figure(figsize=(10, 5))
sns.lineplot(x=df_price_trend["Manufacturer"], y=df_price_trend["Price"], marker='o', color='purple')
plt.title("Tren Harga Rata-rata per Merek Laptop")
plt.xlabel("Merek Laptop")
plt.ylabel("Harga Rata-rata")
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
# Membuat histogram distribusi RAM laptop
plt.figure(figsize=(8, 5))
plt.hist(df["RAM"], bins=10, color="green", edgecolor="black")
plt.title("Distribusi RAM Laptop")
plt.xlabel("RAM (GB)")
plt.ylabel("Frekuensi")
plt.show()

# %%
# Histogram Seaborn
plt.figure(figsize=(8, 5))
sns.histplot(df['RAM'], bins=20, kde=True, color='blue')
plt.title('Distribusi RAM Laptop')
plt.xlabel('Ram (GB)')
plt.ylabel('Frekuensi')
plt.show()

# %%
# Membuat Boxplot Berat Laptop berdasarkan Merek Laptop
plt.figure(figsize=(10, 5))
sns.boxplot(x="Manufacturer", y="Weight", data=df, palette="coolwarm")
plt.title("Distribusi Berat Laptop berdasarkan Merek")
plt.xlabel("Merek Laptop")
plt.ylabel("Berat (kg)")
plt.xticks(rotation=45)
plt.grid()
plt.show()
# Out:
# <ipython-input-72-490100e0c5e2>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Manufacturer", y="Weight", data=df, palette="coolwarm")

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x="Manufacturer", y="Weight", data=df, palette="coolwarm")
plt.title("Distribusi Berat Laptop berdasarkan Merek")
plt.xlabel("Merek Laptop")
plt.ylabel("Berat (kg)")
plt.xticks(rotation=45)
plt.grid()
plt.show()
# Out:
# <ipython-input-94-6d341080d4a4>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Manufacturer", y="Weight", data=df, palette="coolwarm")

# %%
# Scatter Plot Harga vs RAM
plt.figure(figsize=(8, 5))
plt.scatter(df["RAM"], df["Price"], c="blue", alpha=0.5)
plt.title("Scatter Plot: RAM vs Harga Laptop")
plt.xlabel("RAM (GB)")
plt.ylabel("Harga Laptop")
plt.grid()
plt.show()

# %%
# Scatter Plot Seaborn
plt.figure(figsize=(8, 5))
sns.scatterplot(x="RAM", y="Price", data=df, color="red", alpha=0.6)
plt.title("Scatter Plot: RAM vs Harga Laptop")
plt.xlabel("RAM (GB)")
plt.ylabel("Harga Laptop")
plt.grid()
plt.show()

# %%
# Pilih hanya kolom numerik yang ada dalam dataset
numerical_columns = df.select_dtypes(include=["number"]).columns
df_corr = df[numerical_columns].corr()
plt.figure(figsize=(8, 5))
sns.heatmap(df_corr, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap Korelasi Antar Variabel Numerik")
plt.show()

# %% [markdown]
# ### Insight & Tindakan

# %% [markdown]
# Insight:
# - Harga laptop lebih dipengaruhi oleh RAM & prosesor daripada storage.
# - Laptop dengan RAM 8GB adalah yang paling populer di pasaran.
# - Harga laptop cenderung naik seiring waktu, jadi pembelian lebih awal bisa lebih hemat.
# - Retailer harus menyesuaikan strategi pemasaran dengan segmentasi pelanggan.
# - Pelanggan sebaiknya memilih spesifikasi berdasarkan kebutuhan daripada hanya melihat harga.
# - RAM lebih besar (16GB & 32GB) mulai meningkat dalam ketersediaannya, menunjukkan permintaan untuk laptop performa tinggi.
# - Laptop dengan RAM 4GB atau lebih kecil semakin jarang ditemukan, menunjukkan bahwa spesifikasi rendah mulai ditinggalkan
#
# Tindakan:
# - Retailer sebaiknya fokus menjual laptop dengan RAM 8GB atau lebih karena paling banyak diminati.
# - Produsen dapat meningkatkan produksi laptop dengan RAM 16GB atau lebih untuk memenuhi permintaan pasar yang berkembang ke arah performa tinggi.
# - Retailer sebaiknya mengelompokkan produk berdasarkan segmentasi harga untuk memudahkan pelanggan memilih.
# - Pelanggan bisa memilih laptop berdasarkan kebutuhan mereka daripada hanya berdasarkan harga.
# - Pelanggan yang mencari laptop untuk kerja berat (editing, gaming) sebaiknya fokus pada RAM & prosesor daripada sekadar kapasitas penyimpanan.
